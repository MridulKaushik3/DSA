# %% [markdown]
# # Binary Search Tree Implement

# %%
class BST:
    def __init__(self,key):
        self.key = key
        self.lchild = None
        self.rchild = None

root = BST(10)
root.lchild = BST(5)
print(root.key)
print(root.lchild.key, root.lchild)
print(root.rchild)
# Out:
# 10
# 5 <__main__.BST object at 0x000001CAA963F050>
# None

# %% [markdown]
# ## Insertion

# %%
class BST:
    def __init__(self,key):
        self.key = key
        self.lchild = None
        self.rchild = None

    def insert(self, data):
        if self.key is None :
            self.key = data
            return
        
        #Ignoring Duplicate
        if self.key ==data:
            return

        if self.key>data:
            if self.lchild:
                self.lchild.insert(data)
            else:
                self.lchild = BST(data)
        else:
            if self.rchild:
                self.rchild.insert(data)
            else:
                self.rchild = BST(data)

root = BST(10)
root.insert(5)
root.insert(20)

# %% [markdown]
# ## Search

# %%
class BST:
    def __init__(self,key):
        self.key = key
        self.lchild = None
        self.rchild = None

    def insert(self, data):
        if self.key is None :
            self.key = data
            return
        
        #Ignoring Duplicate
        if self.key ==data:
            return

        if self.key>data:
            if self.lchild:
                self.lchild.insert(data)
            else:
                self.lchild = BST(data)
        else:
            if self.rchild:
                self.rchild.insert(data)
            else:
                self.rchild = BST(data)
        
    def search(self, data):
        if self.key == data:
            print("Found")
            return
        if self.key>data:
            if self.lchild:
                self.lchild.search(data)
            else:
                print("Not Found")
        else:
            if self.rchild:
                self.rchild.search(data)
            else:
                print("Not Found")

root = BST(None)
list1 = [10,20,30,40,50]

for i in list1:
    root.insert(i)

root.search(30)
# Out:
# Found

# %% [markdown]
# ## Pre Order Traversal

# %%
class BST:
    def __init__(self,key):
        self.key = key
        self.lchild = None
        self.rchild = None

    def insert(self, data):
        if self.key is None :
            self.key = data
            return
        
        #Ignoring Duplicate
        if self.key ==data:
            return

        if self.key>data:
            if self.lchild:
                self.lchild.insert(data)
            else:
                self.lchild = BST(data)
        else:
            if self.rchild:
                self.rchild.insert(data)
            else:
                self.rchild = BST(data)
        
    def search(self, data):
        if self.key == data:
            print("Found")
            return
        if self.key>data:
            if self.lchild:
                self.lchild.search(data)
            else:
                print("Not Found")
        else:
            if self.rchild:
                self.rchild.search(data)
            else:
                print("Not Found")
    
    def preorder(self):
        print(self.key)
        if self.lchild:
            self.lchild.preorder()
        if self.rchild:
            self.rchild.preorder()

        
root = BST(10)
list1 = [6,3,1,6,98,3,7]

for i in list1:
    root.insert(i)

root.preorder()
# Out:
# 10
# 6
# 3
# 1
# 7
# 98

# %% [markdown]
# ## Inorder Traversal

# %%
class BST:
    def __init__(self,key):
        self.key = key
        self.lchild = None
        self.rchild = None

    def insert(self, data):
        if self.key is None :
            self.key = data
            return
        
        #Ignoring Duplicate
        if self.key ==data:
            return

        if self.key>data:
            if self.lchild:
                self.lchild.insert(data)
            else:
                self.lchild = BST(data)
        else:
            if self.rchild:
                self.rchild.insert(data)
            else:
                self.rchild = BST(data)
        
    def search(self, data):
        if self.key == data:
            print("Found")
            return
        if self.key>data:
            if self.lchild:
                self.lchild.search(data)
            else:
                print("Not Found")
        else:
            if self.rchild:
                self.rchild.search(data)
            else:
                print("Not Found")
    
    def preorder(self):
        print(self.key, end=" ")
        if self.lchild:
            self.lchild.preorder()
        if self.rchild:
            self.rchild.preorder()

    def inorder(self):
        if self.lchild:
            self.lchild.inorder()
        print(self.key, end=" ")
        if self.rchild:
            self.rchild.preorder()


root = BST(10)
list1 = [6,3,1,6,98,3,7]

for i in list1:
    root.insert(i)
print("Preorder")
root.preorder() 
print()
print("Inorder")
root.inorder()
# Out:
# Preorder
# 10 6 3 1 7 98 Inorder
# 1 3 6 7 10 98

# %% [markdown]
# ## Postorder Traversal

# %%
class BST:
    def __init__(self,key):
        self.key = key
        self.lchild = None
        self.rchild = None

    def insert(self, data):
        if self.key is None :
            self.key = data
            return
        
        #Ignoring Duplicate
        if self.key ==data:
            return

        if self.key>data:
            if self.lchild:
                self.lchild.insert(data)
            else:
                self.lchild = BST(data)
        else:
            if self.rchild:
                self.rchild.insert(data)
            else:
                self.rchild = BST(data)
        
    def search(self, data):
        if self.key == data:
            print("Found")
            return
        if self.key>data:
            if self.lchild:
                self.lchild.search(data)
            else:
                print("Not Found")
        else:
            if self.rchild:
                self.rchild.search(data)
            else:
                print("Not Found")
    
    def preorder(self):
        print(self.key, end=" ")
        if self.lchild:
            self.lchild.preorder()
        if self.rchild:
            self.rchild.preorder()

    def inorder(self):
        if self.lchild:
            self.lchild.inorder()
        print(self.key, end=" ")
        if self.rchild:
            self.rchild.preorder()

    def postorder(self):
        if self.lchild:
            self.lchild.postorder()
        if self.rchild:
            self.rchild.postorder()
        print(self.key, end=" ")

root = BST(10)
list1 = [6,3,1,6,98,3,7]

for i in list1:
    root.insert(i)
print("Preorder")
root.preorder() 
print()
print("Inorder")
root.inorder()
print()
print("Postorder")
root.postorder()
# Out:
# Preorder
# 10 6 3 1 7 98 Inorder
# 1 3 6 7 10 98 Postorder
# 1 3 7 6 98 10

# %% [markdown]
# ## Deletion
# ### (Except Root Node 1 Child)

# %%
class BST:
    def __init__(self,key):
        self.key = key
        self.lchild = None
        self.rchild = None

    def insert(self, data):
        if self.key is None :
            self.key = data
            return
        
        #Ignoring Duplicate
        if self.key ==data:
            return

        if self.key>data:
            if self.lchild:
                self.lchild.insert(data)
            else:
                self.lchild = BST(data)
        else:
            if self.rchild:
                self.rchild.insert(data)
            else:
                self.rchild = BST(data)
        
    def search(self, data):
        if self.key == data:
            print("Found")
            return
        if self.key>data:
            if self.lchild:
                self.lchild.search(data)
            else:
                print("Not Found")
        else:
            if self.rchild:
                self.rchild.search(data)
            else:
                print("Not Found")
    
    def preorder(self):
        print(self.key, end=" ")
        if self.lchild:
            self.lchild.preorder()
        if self.rchild:
            self.rchild.preorder()

    def inorder(self):
        if self.lchild:
            self.lchild.inorder()
        print(self.key, end=" ")
        if self.rchild:
            self.rchild.preorder()

    def postorder(self):
        if self.lchild:
            self.lchild.postorder()
        if self.rchild:
            self.rchild.postorder()
        print(self.key, end=" ")
    
    def delete(self,data):
        if self.key is None:
            print("Empty Tree")
            return
        if data < self.key:
            if self.lchild:
                self.lchild = self.lchild.delete(data)
            else:
                print("Not Present")
                return
        elif data > self.key:
            if self.rchild:
                self.rchild = self.rchild.delete(data)
            else:
                print("Not Present")
                return
        else:
            if self.lchild is None:
                temp = self.rchild
                self = None
                return temp
            if self.rchild is None:
                temp = self.lchild
                self = None
                return temp  
            node = self.rchild
            while node.lchild:
                node = node.lchild
            self.key = node.key
            self.rchild = self.rchild.delete(node.key)
        return self
root = BST(10)
list1 = [6,3,1,6,98,3,7]
for i in list1:
    root.insert(i)
root.preorder()
root.delete(6)
print()
root.preorder()
# Out:
# 10 6 3 1 7 98

# %% [markdown]
# ### Deleting root node

# %%
class BST:
    def __init__(self,key):
        self.key = key
        self.lchild = None
        self.rchild = None

    def insert(self, data):
        if self.key is None :
            self.key = data
            return
        
        #Ignoring Duplicate
        if self.key ==data:
            return

        if self.key>data:
            if self.lchild:
                self.lchild.insert(data)
            else:
                self.lchild = BST(data)
        else:
            if self.rchild:
                self.rchild.insert(data)
            else:
                self.rchild = BST(data)
        
    def search(self, data):
        if self.key == data:
            print("Found")
            return
        if self.key>data:
            if self.lchild:
                self.lchild.search(data)
            else:
                print("Not Found")
        else:
            if self.rchild:
                self.rchild.search(data)
            else:
                print("Not Found")
    
    def preorder(self):
        print(self.key, end=" ")
        if self.lchild:
            self.lchild.preorder()
        if self.rchild:
            self.rchild.preorder()

    def inorder(self):
        if self.lchild:
            self.lchild.inorder()
        print(self.key, end=" ")
        if self.rchild:
            self.rchild.preorder()

    def postorder(self):
        if self.lchild:
            self.lchild.postorder()
        if self.rchild:
            self.rchild.postorder()
        print(self.key, end=" ")
    
    def delete(self,data,curr):
        if self.key is None:
            print("Empty Tree")
            return
        if data < self.key:
            if self.lchild:
                self.lchild = self.lchild.delete(data)
            else:
                print("Not Present")
                return
        elif data > self.key:
            if self.rchild:
                self.rchild = self.rchild.delete(data)
            else:
                print("Not Present")
                return
        else:
            if self.lchild is None:
                temp = self.rchild
                if data ==curr:
                    self.key = temp.key
                    self.lchild = temp.lchild
                    self.rchild = temp.rchild
                    temp = None
                    return
                self = None
                return temp
            if self.rchild is None:
                temp = self.lchild
                if data ==curr:
                    self.key = temp.key
                    self.lchild = temp.lchild
                    self.rchild = temp.rchild
                    temp = None
                    return
                self = None
                return temp  
            node = self.rchild
            while node.lchild:
                node = node.lchild
            self.key = node.key
            self.rchild = self.rchild.delete(node.key)
        return self
    
def count(node):
    if node is None:
        return 0
    return 1+count(node.lchid)+count(node.rchild)

root = BST(10)
list1 = [6,3,1,6,98,3,7]
for i in list1:
    root.insert(i)
root.preorder()

print()
root.preorder()
